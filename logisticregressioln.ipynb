# %% [markdown]
# <a href="https://colab.research.google.com/github/praneshnikhar/Machinelearning/blob/main/logisticregressioln.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
#only numpy is required for logistic regression

# %%
 class Logistic_Regression():

  def __init__(self , learning_rate, no_of_iterations):
    self.learning_rate = learning_rate
    self.no_of_iterations = no_of_iterations

  #fit function to a dataset
  def fit(self, X, Y):
    self.m, self.n = X.shape

    #initiating weight and bias value
    self.w = np.zeros(self.n)

    self.b = 0
    self.X = X
    self.Y = Y

    #implementing gradient descent for optimisation
    for i in range(np_of_iterations):
      self.update_weights()

  def update_weights(self):

    #Y_hat formula (sigmoid)
    Y_hat = 1/(1+np.ex( - (self.X.dot(self.w) + self.b))) #z = wx+b

    dw = (1/self.m)*np.dot(self.X.Y,(Y_hat - self.Y))
    db = (1/self.m)*np.sum(Y_hat - self.Y)

    self.w = self.w - self.learning_rate*dw
    self.b = self.b - self.learning_rate*db

  def predict(self):
    Y_pred = 1/(1+np.ex( - (self.X.dot(self.w) + self.b)))
    Y_pred = np.where(Y_pred > 0.5, 1, 0)
    return Y_pred
